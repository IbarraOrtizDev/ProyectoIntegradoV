# %%
from src.modeller import entrenar, predecir
from src.logger import LoggerService

# %%
logger = LoggerService()
# Out:
# Ruta de logs configurada: src/logs
# Directorio de logs creado/verificado en: src/logs
# Archivo de log configurado: src/logs/log_2025-05-25.txt
# Logger configurado exitosamente

# %%
entrenar(logger)
# Out:
#       id   timestamp        open        high         low       close  \
# 0     50  1710336600  143.050003  143.229996  141.369995  142.139999
# 1     51  1710423000  142.610001  143.100006  139.020004  139.619995
# 2     52  1710509400  135.440002  137.699997  134.630005  136.979996
# 3     53  1710768600  140.179993  141.539993  136.610001  136.639999
# 4     54  1710855000  135.300003  136.270004  133.029999  134.869995
# ..   ...         ...         ...         ...         ...         ...
# 296  346  1747684801  189.000000  193.500000  188.811005  193.500000
# 297  347  1747771202  191.800003  193.720001  190.809998  193.449997
# 298  348  1747857602  193.100006  195.259995  190.529999  191.759995
# 299  349  1747944002  191.339996  196.830002  191.360001  196.190002
# 300  350  1748007000  192.020004  192.800003  190.029999  191.979996
#
#        volume    adjclose                      date symbol  ...        rsi  \
# ...

# %%
predecir(logger)
# Out:
# {'prediccion': 0,
#  'probabilidad': 0.004816742148250341,
#  'threshold': 0.49999999999999994,
#  'fecha': Timestamp('2025-05-23 09:30:00+0000', tz='UTC'),
#  'precio_actual': 191.97999572753903,
#  'metricas_modelo': {'rmse': 0.30010052228676876,
#   'mae': 0.15982674062252045,
#   'auc': 0.9632107023411371,
#   'accuracy': 0.8979591836734694,
#   'f1': 0.9056603773584906}}
